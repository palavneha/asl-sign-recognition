# %%
# ASL Sign Recognition Project
# Notebook 1: Data Preprocessing

import os
import cv2
import numpy as np
import matplotlib.pyplot as plt

print("Libraries imported successfully")
# Out:
# Libraries imported successfully

# %%
import os

dataset_path =r"C:\Users\Dell\Desktop\asl-sign-recognition\datasets"
classes = sorted(os.listdir(dataset_path))

print("Total classes:", len(classes))
print("Classes:", classes)
# Out:
# Total classes: 28
# Classes: ['A-samples', 'B-samples', 'C-samples', 'D-samples', 'E-samples', 'F-samples', 'G-samples', 'H-samples', 'I-samples', 'K-samples', 'L-samples', 'M-samples', 'N-samples', 'O-samples', 'P-samples', 'Q-samples', 'R-samples', 'S-samples', 'T-samples', 'U-samples', 'V-samples', 'W-samples', 'X-samples', 'Y-samples', 'hello', 'no', 'please', 'sorry']

# %%
import cv2
import numpy as np
import os

IMG_SIZE = 64
X = []
y = []
labels = []

dataset_path =r"C:\Users\Dell\Desktop\asl-sign-recognition\datasets"

for label, class_name in enumerate(sorted(os.listdir(dataset_path))):
    class_path = os.path.join(dataset_path, class_name)
    if not os.path.isdir(class_path):
        continue

    labels.append(class_name)

    for img_name in os.listdir(class_path):
        img_path = os.path.join(class_path, img_name)
        img = cv2.imread(img_path)

        if img is None:
            continue

        img = cv2.resize(img, (IMG_SIZE, IMG_SIZE))
        img = img / 255.0  # normalize

        X.append(img)
        y.append(label)

X = np.array(X)
y = np.array(y)

print("Images shape:", X.shape)
print("Labels shape:", y.shape)
# Out:
# Images shape: (2552, 64, 64, 3)
# Labels shape: (2552,)
